# %%
import requests
from IPython.display import HTML
from bs4 import BeautifulSoup
import re
import pandas as pd
import scrape_insta
import json.decoder as decoder

# %%
pic1 = scrape_insta.scrape_info('https://www.instagram.com/p/BbCdRZRFzxL/?taken-by=thedriftcollective')

# %%
pic2 = scrape_insta.scrape_info('https://www.instagram.com/p/Bd0IxZ5HXiU/?taken-by=thedriftcollective')

# %%
(str(pic1['hashtags'])).split(',')
# Out:
# ["['#shopsmall'",
#  " '#handmade'",
#  " '#recreatedapparel'",
#  " '#sustainablefashion'",
#  " '#portsmouthnh']"]

# %%
df = pd.DataFrame([list(pic1.values())], columns=list(pic1.keys()))

# %%
df
# Out:
#    number_of_likes                                            caption  \
# 0              226  FLANNEL TIME ⚡️ $20 Drift Flannel Sale starts ...
#
#                                             hashtags  \
# 0  [#shopsmall, #handmade, #recreatedapparel, #su...
#
#                                             comments        people_tagged   \
# 0  [@_tatiiib 👀👀👀, really diggin your threads 😍⚡️...  [thedriftcollective]
#
#    number_of_comments
# 0                   3

# %%
df.append(pd.DataFrame([list(pic2.values())], columns=list(pic2.keys())))
# Out:
#    number_of_likes                                            caption  \
# 0              226  FLANNEL TIME ⚡️ $20 Drift Flannel Sale starts ...
# 0              317  Dreaming about Summertime and Drift surf trips...
#
#                                             hashtags  \
# 0  [#shopsmall, #handmade, #recreatedapparel, #su...
# 0  [#summersunselection, #featurepalette, #justgo...
#
#                                             comments  \
# 0  [@_tatiiib 👀👀👀, really diggin your threads 😍⚡️...
# 0  [Mex In a few mths!!! @thedriftcollective, @ja...
#
#                                people_tagged   number_of_comments
# 0                        [thedriftcollective]                   3
# 0  [idforreal, sea__soul, thedriftcollective]                   5

# %%
response = requests.get('https://www.instagram.com/p/BdkrH7uHkpr/?taken-by=thedriftcollective.html')
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup.find_all('body',{'div':{'div._pfyik._lz8g1':{'div._23gmb':{'div._klr3f':{'div._1se52':'a._3a693.coreSpriteRightPaginationArrow'}}}}})
# Out:
# []

# %%
soup.find_all({'id':"fb-root"})
# Out:
# []

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]>      <html lang="en" class="no-js lt-ie9 lt-ie8 lt-ie7 not-logged-in client-root"> <![endif]-->\n<!--[if IE 7]>         <html lang="en" class="no-js lt-ie9 lt-ie8 not-logged-in client-root"> <![endif]-->\n<!--[if IE 8]>         <html lang="en" class="no-js lt-ie9 not-logged-in client-root"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en" class="no-js not-logged-in client-root"> <!--<![endif]-->\n    <head><meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n        <title>\nInstagram\n</title>\n\n        \n        <meta name="robots" content="noimageindex, noarchive">\n        <meta name="mobile-web-app-capable" content="yes">\n        <meta name="theme-color" content="#000000">\n        <meta id="viewport" name="viewport" content="width=device-width, user-scalable=no, initial-scale=1, minimum-scale=1, maximum-scale=1">\n        \n\n        <link rel="manifest" href="/data/manifest.json">\n\n        \n      
# ...

# %%
soup.find_all('a', {'class' : 'notranslate'})
# Out:
# []

# %%
from selenium import webdriver
import selenium
import time

# %%
browser = webdriver.Firefox()

# %%
browser.get('https://www.instagram.com/p/BdvF02znblm/?taken-by=thedriftcollective.html')

# %%
search_box = browser.find_element_by_css_selector("_3a693 coreSpriteRightPag")

# %%
import json.decoder as decoder

# %%
decode = decoder.JSONDecoder()

# %%
for i in soup.find_all("script", {"type":"text/javascript"}):
    if (re.findall('sharedData', str(i))):
        raw = re.sub('<.+?>', '', str(i)) 
        new_raw =raw[21:-1]
        content = decode.decode(new_raw)

# %%
post_content = content['entry_data']['PostPage'][0]['graphql']['shortcode_media']

# %%
post_content;

# %%
number_of_likes = post_content['edge_media_preview_like']['count']
caption = post_content['edge_media_to_caption']['edges'][0]['node']['text']
number_of_comments= post_content['edge_media_to_comment']['count']
people_tagged = [tagged['node']['user']['username'] for tagged in post_content['edge_media_to_tagged_user']['edges']]
hashtags = [tag.strip() for tag in re.findall('\#.+?\s', post_content['edge_media_to_comment']['edges'][0]['node']['text'])]
comments =[]
commenters=[]
for i in range(1,number_of_comments):
    comments.append(post_content['edge_media_to_comment']['edges'][i]['node']['text'])
    commenters.append(post_content['edge_media_to_comment']['edges'][i]['node']['owner']['username'])

# %%
content_list= []
for entry in dics:
    content = dict()
    for i in re.findall('.+?[\,\}]', entry):
        i= re.sub('[\{\}]','',i)
        j = re.findall('.+?\:\s',i)
        print(j)
        k = re.findall(':.+',i)
        print(k)
        j= re.sub('"', '',j[0])
        k= re.sub('"', '',k[0])
        j= j.strip()
        j = j[:-1]
        k= k[1 :]
        k= re.sub(',', '',k)
        k=k.strip()
        if j not in content.keys():
            content[j] = k
        else: print(j)
    content_list.append(content)
# Out:
# [autoreload of scrape_insta failed: Traceback (most recent call last):
#   File "/Applications/anaconda/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/kaitlinstearns/galvanize/CapstoneProject/scrape_insta.py", line 62
#     is_more= True
#           ^
# IndentationError: expected an indented block
# ]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-f4756749536f> in <module>()
#       1 content_list= []
# ----> 2 for entry in dics:
#       3     content = dict()
#       4     for i in re.findall('.+?[\,\}]', entry):
#       5         i= re.sub('[\{\}]','',i)
#
# NameError: name 'dics' is not defined

# %%
# Out:
# ', "config_width": 640, "config_height": 800}'

# %%
testing= str(soup.find_all("script", {"type":"text/javascript"})[2])
# Out:
# <script type="text/javascript">window._sharedData = {"activity_counts": null, "config": {"csrf_token": "247psownVUpLt9u7jpuQyVvvz5OVdCBT", "viewer": null}, "country_code": "US", "language_code": "en", "locale": "en_US", "entry_data": {"PostPage": [{"graphql": {"shortcode_media": {"__typename": "GraphImage", "id": "1650910531702683354", "shortcode": "BbpNmG2Fvba", "dimensions": {"height": 1350, "width": 1080}, "gating_info": null, "media_preview": "", "display_url": "https://instagram.fsnc1-1.fna.fbcdn.net/vp/9ce0729b330ff77bc98e173002654aff/5AEACC78/t51.2885-15/e35/23596488_129186711188664_1150964764751429632_n.jpg", "display_resources": [{"src": "https:
# ...

# %%
response = requests.get('https://www.instagram.com/p/BYD3mwmlFB1/?taken-by=thedriftcollective')
soup = BeautifulSoup(response.text, "html.parser")

# %%
re.findall('.........................1503\d\d\d\d\d\d...............', str(soup.find('body')))
# Out:
# ['fdelight", "created_at": 1503329741, "owner": {"id',
#  'ooo cool", "created_at": 1503330601, "owner": {"id',
#  'e, "taken_at_timestamp": 1503328399, "edge_media_p',
#  '3745088_1670472586609813_1503639553_a.jpg", "usern']

# %%
soup.find_all('body',{'timestamp'})
# Out:
# []

# %%
re.findall('....................................................................................................................................................................................................................................................................................................................................................................................................................................timestamp.............', str(soup.find('body')))
# Out:
# ['50x150/25010631_1459433760842789_6128984439528620032_n.jpg", "username": "allieeff"}}}, {"node": {"id": "17884807642187266", "text": "\\ud83d\\udc4f\\ud83c\\udffc", "created_at": 1511422666, "owner": {"id": "1558708237", "profile_pic_url": "https://instagram.fsnc1-1.fna.fbcdn.net/t51.2885-19/s150x150/18723159_1918246045087701_2797046577632378880_a.jpg", "username": "duman_onr"}}}]}, "comments_disabled": false, "taken_at_timestamp": 1503328399']

# %%
dic.keys()
# Out:
# dict_keys(['activity_counts', 'config', 'country_code', 'language_code', 'locale', 'entry_data', 'gatekeepers', 'qe', 'hostname', 'display_properties_server_guess', 'environment_switcher_visible_server_guess', 'platform', 'nonce', 'zero_data', 'rollout_hash', 'probably_has_app', 'show_app_install'])

# %%
dic['entry_data']['PostPage'][0]['graphql']['shortcode_media']['taken_at_timestamp']
# Out:
# 1503328399

# %%
i = soup.find_all('body')[0]
raw = re.sub('<.+?>', '', str(i))
without_header =raw[23:-684]
without_header
# Out:
# '{"activity_counts": null, "config": {"csrf_token": "911sz3iudqQ9bRgF6RNbpEdeuZZfOqmH", "viewer": null}, "country_code": "US", "language_code": "en", "locale": "en_US", "entry_data": {"PostPage": [{"graphql": {"shortcode_media": {"__typename": "GraphImage", "id": "1586356049849634933", "shortcode": "BYD3mwmlFB1", "dimensions": {"height": 1282, "width": 1080}, "gating_info": null, "media_preview": "", "display_url": "https://instagram.fsnc1-1.fna.fbcdn.net/vp/f03e9e87435dfeef56a692091d168492/5AE74D54/t51.2885-15/e35/20968825_286605181745392_2827066397576658944_n.jpg", "display_resources": [{"src": "https://instagram.fsnc1-1.fna.fbcdn.net/vp/a1d25b965f0e5bd5d10a678a9ac57c0b/5AE3F0A2/t51.2885-15/sh0.08/e35/p640x640/20968825_286
# ...

# %%
import json.decoder as decoder

# %%
decode = decoder.JSONDecoder()
dic =decode.decode(without_header)

# %%
dic.keys()
# Out:
# dict_keys(['activity_counts', 'config', 'country_code', 'language_code', 'locale', 'entry_data', 'gatekeepers', 'qe', 'hostname', 'display_properties_server_guess', 'environment_switcher_visible_server_guess', 'platform', 'nonce', 'zero_data', 'rollout_hash', 'probably_has_app', 'show_app_install'])

# %%
for i in soup.contents:
    print (re.findall('div',str(i)))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
urls =['https://www.instagram.com/p/7eVj7oAT0s/?taken-by=thedriftcollective', 'https://www.instagram.com/p/7eV3mQgT1O/?taken-by=thedriftcollective', 'https://www.instagram.com/p/7eW4cbAT23/?taken-by=thedriftcollective', 'https://www.instagram.com/p/7eX24agT4M/?taken-by=thedriftcollective', 'https://www.instagram.com/p/7eZsfSAT6p/?taken-by=thedriftcollective', 'https://www.instagram.com/p/7eamaIgT72/?taken-by=thedriftcollective', 'https://www.instagram.com/p/7ec5c1gT-w/?taken-by=thedriftcollective', 'https://www.instagram.com/p/7iA0KiAT5X/?taken-by=thedriftcollective', 'https://www.instagram.com/p/7iESgXgT__/?taken-by=thedriftcollective', 'https://www.instagram.com/p/7knANuAT9b/?taken-by=thedriftcollective', 'https://www.instagram.com/p/7nGA6DAT6I/?taken-by=thedriftcollective', 'https://www.instagram.com/p/7nUPDsATzF/?taken-by=thedriftcollective', 'https://www.instagram.com/p/7qi2MRgT0D/?taken-by=thedriftcollective', 'https://www.instagram.com/p/7seRJ2gT-t/?taken-by=thedriftcollective', 'https://www.instagram.com/p/7vER6TAT5U/?taken-by=thedriftcollective', 'https://www.instagram.com/p/77ljUMATzw/?taken-by=thedriftcollective', 'https://www.instagram.com/p/8A4wjfAT7X/?taken-by=thedriftcollective', 'https://www.instagram.com/p/8PT7JegT15/?taken-by=thedriftcollective', 'https://www.instagram.com/p/8Vc-sfgT1t/?taken-by=thedriftcollective', 'https://www.instagram.com/p/8d4BPcAT88/?taken-by=thedriftcollective', 'https://www.instagram.com/p/8g7x68gT5G/?taken-by=thedriftcollective']

# %%
len(urls)
# Out:
# 21

# %%
import time

# %%
scrape = scrape_insta.make_insta_dataframe(2)

# %%
dic=scrape.scrape(['https://www.instagram.com/p/Bd8Nc4LnW4T/?taken-by=thedriftcollective'])
# Out:
# https://www.instagram.com/p/Bd8Nc4LnW4T/?taken-by=thedriftcollective

# %%
dic
# Out:
# [{'caption': 'Hand-printed at the Collective 🐟 New apparel on the racks! #thedriftcollective #portsmouthnh',
#   'comments': [],
#   'hashtags': ['#thedriftcollective'],
#   'number_of_comments': 1,
#   'number_of_likes': 184,
#   'people_tagged ': ['thedriftcollective'],
#   'taken_at': 1515956319,
#   'url': 'https://www.instagram.com/p/Bd8Nc4LnW4T/?taken-by=thedriftcollective'}]

# %%
df = scrape.scrape(urls)
# Out:
# https://www.instagram.com/p/7eVj7oAT0s/?taken-by=thedriftcollective
# https://www.instagram.com/p/7eV3mQgT1O/?taken-by=thedriftcollective
# https://www.instagram.com/p/7eW4cbAT23/?taken-by=thedriftcollective
# https://www.instagram.com/p/7eX24agT4M/?taken-by=thedriftcollective
# https://www.instagram.com/p/7eZsfSAT6p/?taken-by=thedriftcollective
# https://www.instagram.com/p/7eamaIgT72/?taken-by=thedriftcollective
# https://www.instagram.com/p/7ec5c1gT-w/?taken-by=thedriftcollective
# https://www.instagram.com/p/7iA0KiAT5X/?taken-by=thedriftcollective
# https://www.instagram.com/p/7iESgXgT__/?taken-by=thedriftcollective
# https://www.instagram.com/p/7knANuAT9b/?taken-by=thedriftcollective
# https://www.instagram.com/p/7nGA6DAT6I/?taken-by=thedriftcollective
# https://www.instagram.com/p/7nUPDsATzF/?taken-by=thedriftcollective
# https://www.instagram.com/p/7qi2MRgT0D/?taken-by=thedriftcollective
# https://www.instagram.com/p/7seRJ2gT-t/?taken-by=thedriftcollective
# ...

# %%
pd.DataFrame(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d5ffc0cb16d7> in <module>()
# ----> 1 pd.DataFrame(df)
#
# NameError: name 'df' is not defined

# %%
scrape.scrape_info('https://www.instagram.com/p/7eV3mQgT1O/?taken-by=thedriftcollective')
# Out:
# 4
# 5
# {'caption': 'Playing hooky with @gradeighboisvert_ // Gradeigh wears her customized bikini bottoms',
#  'comments': [],
#  'hashtags': [],
#  'number_of_comments': 0,
#  'number_of_likes': 36,
#  'people_tagged ': [],
#  'url': 'https://www.instagram.com/p/7eV3mQgT1O/?taken-by=thedriftcollective'}

# %%
more =['https://www.instagram.com/p/8tJ4PZATxy/?taken-by=thedriftcollective', 'https://www.instagram.com/p/859ze7gT8J/?taken-by=thedriftcollective','https://www.instagram.com/p/8_I7lRATxV/?taken-by=thedriftcollective','https://www.instagram.com/p/9OlgTRgT7s/?taken-by=thedriftcollective','https://www.instagram.com/p/9YPVqRgT82/?taken-by=thedriftcollective','https://www.instagram.com/p/9a6L4pAT0i/?taken-by=thedriftcollective','https://www.instagram.com/p/9lO0FtgT7w/?taken-by=thedriftcollective','https://www.instagram.com/p/9s9PFagT5K/?taken-by=thedriftcollective','https://www.instagram.com/p/9ydE8uATyN/?taken-by=thedriftcollective','https://www.instagram.com/p/-RLVZsAT8T/?taken-by=thedriftcollective','https://www.instagram.com/p/-4hEgDATw3/?taken-by=thedriftcollective','https://www.instagram.com/p/-_wYdggTwl/?taken-by=thedriftcollective','https://www.instagram.com/p/_SNEPoAT9N/?taken-by=thedriftcollective','https://www.instagram.com/p/_1541cAT89/?taken-by=thedriftcollective','https://www.instagram.com/p/_4T4dSgT2A/?taken-by=thedriftcollective','https://www.instagram.com/p/BAVVum4gT31/?taken-by=thedriftcollective','https://www.instagram.com/p/BAfNTHSAT2c/?taken-by=thedriftcollective','https://www.instagram.com/p/BAvU5zDAT7o/?taken-by=thedriftcollective','https://www.instagram.com/p/BA8ZPSKgTz-/?taken-by=thedriftcollective','https://www.instagram.com/p/BBGg6bvgTyp/?taken-by=thedriftcollective','https://www.instagram.com/p/BBM_MbMAT6J/?taken-by=thedriftcollective','https://www.instagram.com/p/BBSUAFQgT_o/?taken-by=thedriftcollective','https://www.instagram.com/p/BBYtX3mATxs/?taken-by=thedriftcollective','https://www.instagram.com/p/BBgF0UlgTz8/?taken-by=thedriftcollective','https://www.instagram.com/p/BBndX5rgT3B/?taken-by=thedriftcollective','https://www.instagram.com/p/BBtDHnbgT7V/?taken-by=thedriftcollective','https://www.instagram.com/p/BBufBPmATy5/?taken-by=thedriftcollective','https://www.instagram.com/p/BB5onKiAT9L/?taken-by=thedriftcollective','https://www.instagram.com/p/BCDZ2iJgTyz/?taken-by=thedriftcollective','https://www.instagram.com/p/BCJY9otgT2Z/?taken-by=thedriftcollective','https://www.instagram.com/p/BCMBkUjAT4M/?taken-by=thedriftcollective','https://www.instagram.com/p/BCT4fVEAT3P/?taken-by=thedriftcollective','https://www.instagram.com/p/BCX-HjTAT4w/?taken-by=thedriftcollective','https://www.instagram.com/p/BCgRdFpATxj/?taken-by=thedriftcollective','https://www.instagram.com/p/BCk77mQgTxZ/?taken-by=thedriftcollective','https://www.instagram.com/p/BCk8vQ4gTzI/?taken-by=thedriftcollective','https://www.instagram.com/p/BCoC81bAT3u/?taken-by=thedriftcollective','https://www.instagram.com/p/BCqNoL8gT1y/?taken-by=thedriftcollective','https://www.instagram.com/p/BCsr6a7gT78/?taken-by=thedriftcollective','https://www.instagram.com/p/BCvr77UgTzp/?taken-by=thedriftcollective','https://www.instagram.com/p/BC5oolFAT0y/?taken-by=thedriftcollective','https://www.instagram.com/p/BDEYO-9AT_r/?taken-by=thedriftcollective','https://www.instagram.com/p/BDEZZ4OgTyR/?taken-by=thedriftcollective','https://www.instagram.com/p/BDV6eVJgT8E/?taken-by=thedriftcollective','https://www.instagram.com/p/BDf0irugTzy/?taken-by=thedriftcollective','https://www.instagram.com/p/BDjiKx2gT6a/?taken-by=thedriftcollective','https://www.instagram.com/p/BDoxSGvgTxc/?taken-by=thedriftcollective','https://www.instagram.com/p/BDrWy5rgTzk/?taken-by=thedriftcollective','https://www.instagram.com/p/BDzI4kCgT4Q/?taken-by=thedriftcollective','https://www.instagram.com/p/BD4AGmngT_6/?taken-by=thedriftcollective','https://www.instagram.com/p/BD9E7ZTgT7-/?taken-by=thedriftcollective','https://www.instagram.com/p/BEE-2sJgT1P/?taken-by=thedriftcollective','https://www.instagram.com/p/BEcELwFAT0m/?taken-by=thedriftcollective','https://www.instagram.com/p/BEw8nUyATzf/?taken-by=thedriftcollective','https://www.instagram.com/p/BE7KBO-gT0M/?taken-by=thedriftcollective','https://www.instagram.com/p/BFHmNzcgT-Q/?taken-by=thedriftcollective','https://www.instagram.com/p/BFeF7PJAT5x/?taken-by=thedriftcollective','https://www.instagram.com/p/BFhdckZATxa/?taken-by=thedriftcollective','https://www.instagram.com/p/BFzLzUxAT_q/?taken-by=thedriftcollective','https://www.instagram.com/p/BF7ac0RAT7t/?taken-by=thedriftcollective','https://www.instagram.com/p/BGDOq3JATy0/?taken-by=thedriftcollective','https://www.instagram.com/p/BGIXOVCgT6_/?taken-by=thedriftcollective','https://www.instagram.com/p/BGXuvXngTy7/?taken-by=thedriftcollective','https://www.instagram.com/p/BGnCkEdgT2Y/?taken-by=thedriftcollective','https://www.instagram.com/p/BGp0-QLgT85/?taken-by=thedriftcollective','https://www.instagram.com/p/BGsXRMcgTwV/?taken-by=thedriftcollective','https://www.instagram.com/p/BG5ObVaAT_0/?taken-by=thedriftcollective','https://www.instagram.com/p/BG7vudKgT11/?taken-by=thedriftcollective','https://www.instagram.com/p/BHQTQiHDgN_/?taken-by=thedriftcollective','https://www.instagram.com/p/BHc3HfXjsFa/?taken-by=thedriftcollective','https://www.instagram.com/p/BHiYbRUjLck/?taken-by=thedriftcollective','https://www.instagram.com/p/BHsyiBhDsBH/?taken-by=thedriftcollective','https://www.instagram.com/p/BHx4_xfDC7y/?taken-by=thedriftcollective','https://www.instagram.com/p/BIYDHJkgbKl/?taken-by=thedriftcollective','https://www.instagram.com/p/BIdupupgAxu/?taken-by=thedriftcollective','https://www.instagram.com/p/BIi3R1zgd-J/?taken-by=thedriftcollective']

# %%
len(more)
# Out:
# 76

# %%
more_dict= scrape.scrape(more)
# Out:
# https://www.instagram.com/p/8tJ4PZATxy/?taken-by=thedriftcollective
# https://www.instagram.com/p/859ze7gT8J/?taken-by=thedriftcollective
# https://www.instagram.com/p/8_I7lRATxV/?taken-by=thedriftcollective
# https://www.instagram.com/p/9OlgTRgT7s/?taken-by=thedriftcollective
# https://www.instagram.com/p/9YPVqRgT82/?taken-by=thedriftcollective
# https://www.instagram.com/p/9a6L4pAT0i/?taken-by=thedriftcollective
# https://www.instagram.com/p/9lO0FtgT7w/?taken-by=thedriftcollective
# https://www.instagram.com/p/9s9PFagT5K/?taken-by=thedriftcollective
# https://www.instagram.com/p/9ydE8uATyN/?taken-by=thedriftcollective
# https://www.instagram.com/p/-RLVZsAT8T/?taken-by=thedriftcollective
# https://www.instagram.com/p/-4hEgDATw3/?taken-by=thedriftcollective
# https://www.instagram.com/p/-_wYdggTwl/?taken-by=thedriftcollective
# https://www.instagram.com/p/_SNEPoAT9N/?taken-by=thedriftcollective
# https://www.instagram.com/p/_1541cAT89/?taken-by=thedriftcollective
# ...

# %%
type(more_dict)
# Out:
# list

# %%
more_dict += df

# %%
df2=pd.DataFrame(more_dict)

# %%
scrape = scrape_insta.make_insta_dataframe(2)

# %%
df = scrape.scrape(more[:5])
# Out:
# https://www.instagram.com/p/8tJ4PZATxy/?taken-by=thedriftcollective
# https://www.instagram.com/p/859ze7gT8J/?taken-by=thedriftcollective
# https://www.instagram.com/p/8_I7lRATxV/?taken-by=thedriftcollective
# https://www.instagram.com/p/9OlgTRgT7s/?taken-by=thedriftcollective
# https://www.instagram.com/p/9YPVqRgT82/?taken-by=thedriftcollective

# %%
df
# Out:
#                                              caption  \
# 0  B I K I N I | G I V E A W A Y. To win a limite...
# 1  Golden baby 〰🍊👄〰West Coast Drift adventures 🚌\...
# 2  ➕NEON DREAMS ➕worn by the raddest @drupoo \nHa...
# 3  Scorcher of a day, scorcher of a lady. \n@rosa...
# 4  on the way to the #UK! \nFor the talented @geo...
#
#                                             comments  \
# 0  [@bexreader this is the one I was telling you ...
# 1  [Is this Norah?!?, Beautiful, @gradeighboisver...
# 2  [too cool!, 😍😍😍, Those bottoms are so cute😍, @...
# 3  [Very sweet!, Totally your style @kateananda l...
# 4  [Yay! ❤️❤️❤️, @kittycar0o I'll get you these, ...
#
#                                             hashtags  number_of_comments  \
# 0  [#driftbikinigiveaway, #bikinis, #handmade, #g...                  10
# 1                                                 []                   4
# 2               [#thedriftcollective, #driftbikinis]                   5
# ...

# %%
response = requests.get('https://www.instagram.com/p/Bd2-EnEn5m-/?taken-by=thedriftcollective')
soup = BeautifulSoup(response.text, "html.parser")
decode = decoder.JSONDecoder()

# %%
scrape = scrape_insta.make_insta_dataframe(2)
df = scrape.scrape(['https://www.instagram.com/p/Bd2-EnEn5m-/?taken-by=thedriftcollective'])
# Out:
# https://www.instagram.com/p/Bd2-EnEn5m-/?taken-by=thedriftcollective

# %%
df
# Out:
#                                              caption  \
# 0  KILIM JACKET up on site + in shop! Vintage can...
#
#                                             comments  \
# 0  [I miss me sum @caffekilim, @julia_luff, Loooo...
#
#                          hashtags  number_of_comments  number_of_likes  \
# 0  [#supportlocal, #portsmouthnh]                   7              270
#
#                      people_tagged     taken_at  \
# 0  [caffekilim, thedriftcollective]  1515780483
#
#                                                  url
# 0  https://www.instagram.com/p/Bd2-EnEn5m-/?taken...

# %%
'https://graph.instagram.com/logging_client_events'

# %%
response = requests.get('https://graph.instagram.com/logging_client_events')
soup = BeautifulSoup(response.text, "html.parser")
response.status_code
# Out:
# 400

# %%
soup
# Out:
# {"error":{"message":"Unsupported get request. Please read the Graph API documentation at https:\/\/developers.facebook.com\/docs\/graph-api","type":"GraphMethodException","code":100,"error_subcode":33,"fbtrace_id":"HVfeMIwqySv"}}

# %%
response = requests.get('https://www.instagram.com/graphql/query/?query_id=17888483320059182&variables=%7B%22id%22%3A%222183125078%22%2C%22first%22%3A12%2C%22after%22%3A%22AQAxGXePzEowXlDhh8GSoCu9N-nc_fKWDmBcWG16H1bMfzCYmq_kSp4hcVtZyZEvsB2G2gTNDEItdaP7JtmRn6eCayLWeaTu_ORJZIPvZDROuA%22%7D')
soup = BeautifulSoup(response.text, "html.parser")
response.status_code
# Out:
# 200

# %%
decode = decoder.JSONDecoder()
home_page = decode.decode(str(soup))

# %%
home_page['data']['user']['edge_owner_to_timeline_media'].keys()
# Out:
# dict_keys(['count', 'page_info', 'edges'])

# %%
shortcodes=[]
for i in range(len(home_page['data']['user']['edge_owner_to_timeline_media']['edges'])):
    sc = home_page['data']['user']['edge_owner_to_timeline_media']['edges'][i]['node']['shortcode']
    shortcodes.append(sc)

# %%
shortcodes
# Out:
# ['BXibp_NFe58',
#  'BXdfFg6FbP9',
#  'BXau9RcFYOx',
#  'BXUOM05Ftwu',
#  'BXQfHABlLbh',
#  'BXOzgWPFWfo',
#  'BXLVLXglB2e',
#  'BXI6Pm8Fxd6',
#  'BXGjF01FeOT',
#  'BXDnSyEFufF',
#  'BXB-KSnFbFP',
#  'BXBZuH7ljU8']

# %%
next_page = home_page['data']['user']['edge_owner_to_timeline_media']['page_info']['end_cursor']

# %% [markdown]
# ## format of urls:

# %%
'www.instagram.com/p/{}/?taken-by=thedriftcollective'.format(shortcode)

# %%
response = requests.get('https://www.instagram.com/graphql/query/?query_id=17888483320059182&variables=%7B%22id%22%3A%222183125078%22%2C%22first%22%3A12%2C%22after%22%3A%22AQAxGXePzEowXlDhh8GSoCu9N-nc_fKWDmBcWG16H1bMfzCYmq_kSp4hcVtZyZEvsB2G2gTNDEItdaP7JtmRn6eCayLWeaTu_ORJZIPvZDROuA%22%7D')
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
decode = decoder.JSONDecoder()
home_page = decode.decode(str(soup))

# %%
def scrape_shortcodes(initial_url, sleeptime = 2):
    is_more= True
    shortcodes = []
    next_url = initial_url
    while is_more:
        response = requests.get(next_url)
        print(response.status_code)
        soup = BeautifulSoup(response.text, "html.parser")
        decode = decoder.JSONDecoder()
        home_page = decode.decode(str(soup))
        if home_page['data']['user']['edge_owner_to_timeline_media']['page_info']['has_next_page'] == True:
            nextpage = home_page['data']['user']['edge_owner_to_timeline_media']['page_info']['end_cursor']
            next_url = 'https://www.instagram.com/graphql/query/?query_id=17888483320059182&variables=%7B%22id%22%3A%222183125078%22%2C%22first%22%3A12%2C%22after%22%3A%22{}%22%7D'.format(nextpage)
        else:
            is_more = False
        for i in range(len(home_page['data']['user']['edge_owner_to_timeline_media']['edges'])):
            sc = home_page['data']['user']['edge_owner_to_timeline_media']['edges'][i]['node']['shortcode']
            shortcodes.append(sc)
            time.sleep(sleeptime)
    return shortcodes

# %%
short_codes = scrape_shortcodes('https://www.instagram.com/graphql/query/?query_id=17888483320059182&variables=%7B%22id%22%3A%222183125078%22%2C%22first%22%3A12%2C%22after%22%3A%22AQAxGXePzEowXlDhh8GSoCu9N-nc_fKWDmBcWG16H1bMfzCYmq_kSp4hcVtZyZEvsB2G2gTNDEItdaP7JtmRn6eCayLWeaTu_ORJZIPvZDROuA%22%7D')
# Out:
# 200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-253-f0d95c2995de> in <module>()
# ----> 1 short_codes = scrape_shortcodes('https://www.instagram.com/graphql/query/?query_id=17888483320059182&variables=%7B%22id%22%3A%222183125078%22%2C%22first%22%3A12%2C%22after%22%3A%22AQAxGXePzEowXlDhh8GSoCu9N-nc_fKWDmBcWG16H1bMfzCYmq_kSp4hcVtZyZEvsB2G2gTNDEItdaP7JtmRn6eCayLWeaTu_ORJZIPvZDROuA%22%7D')
#
# <ipython-input-145-1511c9a851eb> in scrape_shortcodes(initial_url, sleeptime)
#      17             sc = home_page['data']['user']['edge_owner_to_timeline_media']['edges'][i]['node']['shortcode']
#      18             shortcodes.append(sc)
# ---> 19             time.sleep(sleeptime)
#      20     return shortcodes
#
# KeyboardInterrupt:

# %%
short_codes
# Out:
# ['BXibp_NFe58',
#  'BXdfFg6FbP9',
#  'BXau9RcFYOx',
#  'BXUOM05Ftwu',
#  'BXQfHABlLbh',
#  'BXOzgWPFWfo',
#  'BXLVLXglB2e',
#  'BXI6Pm8Fxd6',
#  'BXGjF01FeOT',
#  'BXDnSyEFufF',
#  'BXB-KSnFbFP',
#  'BXBZuH7ljU8',
#  'BW_eLS1leTB',
#  'BW-NCNoFYW3',
#  'BW87P9slHjl',
#  'BW8BgCqlM3i',
#  'BW6gAehlc-x',
#  'BW2uGY_FqnM',
#  'BW0nS6plxJD',
#  'BWwGvIOFs2X',
#  'BWtXXL5lqHi',
#  'BWsAmuoFzoz',
#  'BWrA9jzFBcl',
#  'BWoJqo3FeAo',
#  'BWk7PHbFESt',
#  'BWfQF7qFdND',
#  'BWbVbuqFkDf',
#  'BWYswDjlLS8',
#  'BWViZXSFdrJ',
#  'BWQYijYl-og',
#  'BWNlASxlV0l',
#  'BWG4OPOlQ27',
#  'BWDlh7nldUo',
#  'BV5DIDCFDXS',
#  'BV2RbHDFXB5',
#  'BV0G8DZlL8E',
#  'BVupEJ4lx9K',
#  'BVtPNZpljfi',
#  'BVp3l6jlJx7',
#  'BVn7zSUFfgv',
#  'BVkPTJklaCX',
#  'BVhtH-kFKXP',
#  'BVfarXZliJe',
#  'BVbHBdjlNpj',
#  'BVVLOU7FVkX',
#  'BVTIkEOl1EK',
#  'BVPw9rclZmU',
#  'BVFsYQyltEz',
#  'BVD2MUFFQ7t',
#  'BVBAGI9l0Pz',
#  'BU9eU-YFZF-',
#  'BU7h8GVlDRq',
#  'BU0blo3Fm9n',
#  'BUyDn9wFTPn',
#  'BUwu5XlFzK_',
# ...

# %%
with open('shortcode.txt', 'w') as file_handler:
    for code in short_codes:
        file_handler.write("{}\n".format(code))

# %%
url = 'www.instagram.com/p/{}/?taken-by=thedriftcollective'.format(shortcode)

# %%
scrape = scrape_insta.make_insta_dataframe(sleep=2)

# %%
df = scrape.scrape(short_codes, shortcode=True)
# Out:
# 1 of 307
# 2 of 307
# 3 of 307
# 4 of 307
# 5 of 307
# 6 of 307
# 7 of 307
# 8 of 307
# 9 of 307
# 10 of 307
# 11 of 307
# 12 of 307
# 13 of 307
# 14 of 307
# 15 of 307
# 16 of 307
# 17 of 307
# 18 of 307
# 19 of 307
# 20 of 307
# 21 of 307
# 22 of 307
# 23 of 307
# 24 of 307
# 25 of 307
# 26 of 307
# 27 of 307
# 28 of 307
# 29 of 307
# 30 of 307
# 31 of 307
# 32 of 307
# 33 of 307
# 34 of 307
# 35 of 307
# 36 of 307
# 37 of 307
# 38 of 307
# 39 of 307
# 40 of 307
# 41 of 307
# 42 of 307
# 43 of 307
# 44 of 307
# 45 of 307
# 46 of 307
# 47 of 307
# 48 of 307
# 49 of 307
# 50 of 307
# 51 of 307
# 52 of 307
# 53 of 307
# 54 of 307
# 55 of 307
# 56 of 307
# 57 of 307
# 58 of 307
# 59 of 307
# 60 of 307
# 61 of 307
# 62 of 307
# 63 of 307
# 64 of 307
# 65 of 307
# 66 of 307
# 67 of 307
# 68 of 307
# 69 of 307
# 70 of 307
# 71 of 307
# 72 of 307
# 73 of 307
# 74 of 307
# 75 of 307
# 76 of 307
# 77 of 307
# 78 of 307
# 79 of 307
# 80 of 307
# 81 of 307
# 82 of 307
# 83 of 307
# 84 of 307
# ...

# %%
short_codes[86]
# Out:
# 'BTsYrmWFXsy'

# %%
df.sort_values('taken_at', ascending=False, inplace=True)

# %%
df =scrape.scrape([short_codes[86]], shortcode=True)
# Out:
# 1 of 1

# %%
df
# Out:
#                                                caption  \
# 0    SHOP OPEN TODAY 🌈 Opening doors at noon today,...
# 1    Summer nights staple 🌊More screen printed guys...
# 2    Come by the shop to check out our Saturday $AL...
# 3    Biarritz with @bubblerock 〰 #thedriftcollectiv...
# 4    Salty Rituals : Super 8 🎥 • shot by @sea__soul...
# 5    Dip dyed denim + Beachbum on camo ⚡️🌈🌊 Availab...
# 6    EXTENDED SALE! People were stoked on yesterday...
# 7    Surprise Saturday Sale 🌈 1/2 off ALL original ...
# 8    ACID WASH RESTOCK at the shop! Hand-dyed  vint...
# 9    @chelsea_pow looking stunning while performing...
# 10   The Candy Cru 🍬 Recreated vintage crewneck tha...
# 11   Moody paradise 👁‍🗨shot by @jakethejedi // #the...
# 12   Babe @brittacarrico in her Snakebite bikini se...
# 13   Spontaneous decision: we're OPEN today at 11! ...
# 14   Restocked our collection of dip-dyed button up...
# 15   Hometown paradise 〰 @idforreal in his Beachbum...
# ...

# %%
url ='http://www.instagram.com/p/{}/?taken-by=thedriftcollective'.format(short_codes[86])

# %%
url= 'https://www.instagram.com/p/BXUOM05Ftwu/?taken-by=thedriftcollective'

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
decode = decoder.JSONDecoder()
for i in soup.find_all("script", {"type":"text/javascript"}):
    if (re.findall('sharedData', str(i))):
        raw = re.sub('<.+?>', '', str(i))        
without_header =raw[21:-1]
content = decode.decode(without_header)
post_content = content['entry_data']['PostPage'][0]['graphql']['shortcode_media']
number_of_comments = len(post_content['edge_media_to_comment']['edges'])

# %%
people_tagged = [tagged['node']['user']['username'] for tagged in post_content['edge_media_to_tagged_user']['edges']]
hashtags =[]
comments=[]
commenters=[]
if post_content['edge_media_to_comment']['edges']:
    if post_content['edge_media_to_comment']['edges'][0]['node']['owner']['username'] == 'thedriftcollective': 
        number_of_comments -= 1
        print(number_of_comments)
        for i in range(1,number_of_comments + 1):
            print(post_content['edge_media_to_comment']['edges'][i]['node']['text'])
            comments.append(post_content['edge_media_to_comment']['edges'][i]['node']['text'])
            commenters.append(post_content['edge_media_to_comment']['edges'][i]['node']['owner']['username'])
# Out:
# 1
# Love thisssss!

# %%
post_content['edge_media_to_comment']['edges'][1]['node']['text']
# Out:
# 'Love thisssss!'

# %%
comments
# Out:
# ['Love thisssss!']

# %%
for i in range(1,2):
    print(i)
# Out:
# 1

# %%
post_content['edge_media_to_comment']['count']
# Out:
# 8

# %%
['dsf','gb']+['er','sfdg']
# Out:
# ['dsf', 'gb', 'er', 'sfdg']

# %%
url2 ='http://www.instagram.com/p/{}/?taken-by=thedriftcollective'.format(short_codes[87])

# %%
response2 = requests.get(url2)
soup2 = BeautifulSoup(response2.text, "html.parser")
decode2 = decoder.JSONDecoder()
for i in soup2.find_all("script", {"type":"text/javascript"}):
    if (re.findall('sharedData', str(i))):
        raw2 = re.sub('<.+?>', '', str(i))        
without_header2 =raw2[21:-1]
content2 = decode.decode(without_header2)
post_content2 = content2['entry_data']['PostPage'][0]['graphql']['shortcode_media']
number_of_comments2 = len(post_content['edge_media_to_comment']['edges'])

# %%
number_of_comments2
# Out:
# 4

# %%
len(post_content2['edge_media_to_comment']['edges'])
# Out:
# 4

# %%
scrape.scrape(['https://www.instagram.com/p/BXUOM05Ftwu/?taken-by=thedriftcollective'])
# Out:
# 0 of 1
#                                              caption      commenters  \
# 0  Biarritz with @bubblerock 〰 #thedriftcollectiv...  [isabelletodd]
#
#            comments                                           hashtags  \
# 0  [Love thisssss!]  [#thedriftcollective, #hinfluencercollective, ...
#
#    number_of_comments  number_of_likes people_tagged     taken_at  \
# 0                   1              318   [bubblerock]  1501729632
#
#                                                  url
# 0  https://www.instagram.com/p/BXUOM05Ftwu/?taken...

# %%
scrape.scrape_shortcodes('https://www.instagram.com/graphql/query/?query_id=17888483320059182&variables=%7B%22id%22%3A%222183125078%22%2C%22first%22%3A12%2C%22after%22%3A%22AQB3GUiXeGwoaxyW_RyElWbgcGBbUOIImoB5Z8LaIDV_pWdJ1HUX8p4eIxCTTy51YEMM061kwk1My4rbU8kcqUmzkiXLvOZAXCFRigqerZ_bBA%22%7D')
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
df = scrape.scrape(scrape.shortcodes, shortcode=True)
# Out:
# 1 of 392
# 2 of 392
# 3 of 392
# 4 of 392
# 5 of 392
# 6 of 392
# 7 of 392
# 8 of 392
# 9 of 392
# 10 of 392
# 11 of 392
# 12 of 392
# 13 of 392
# 14 of 392
# 15 of 392
# 16 of 392
# 17 of 392
# 18 of 392
# 19 of 392
# 20 of 392
# 21 of 392
# 22 of 392
# 23 of 392
# 24 of 392
# 25 of 392
# 26 of 392
# 27 of 392
# 28 of 392
# 29 of 392
# 30 of 392
# 31 of 392
# 32 of 392
# 33 of 392
# 34 of 392
# 35 of 392
# 36 of 392
# 37 of 392
# 38 of 392
# 39 of 392
# 40 of 392
# 41 of 392
# 42 of 392
# 43 of 392
# 44 of 392
# 45 of 392
# 46 of 392
# 47 of 392
# 48 of 392
# 49 of 392
# 50 of 392
# 51 of 392
# 52 of 392
# 53 of 392
# 54 of 392
# 55 of 392
# 56 of 392
# 57 of 392
# 58 of 392
# 59 of 392
# 60 of 392
# 61 of 392
# 62 of 392
# 63 of 392
# 64 of 392
# 65 of 392
# 66 of 392
# 67 of 392
# 68 of 392
# 69 of 392
# 70 of 392
# 71 of 392
# 72 of 392
# 73 of 392
# 74 of 392
# 75 of 392
# 76 of 392
# 77 of 392
# 78 of 392
# 79 of 392
# 80 of 392
# 81 of 392
# 82 of 392
# 83 of 392
# 84 of 392
# ...

# %%
df
# Out:
#                                                caption  \
# 0    Merry Christmas Eve ⭐️ Come celebrate and fini...
# 1    🔥🔥🔥 You deserve to dress one of a kind. Our di...
# 2    Everyone could use some acid wash under the tr...
# 3    Hand printed, dyed , and crafted. Shopping Dri...
# 4    LAST MINUTE SHOPPERS SALE 🎁 Haven't bought a s...
# 5    HOLIDAY HOURS ⭐️⭐️⭐️\nToday-Saturday 11-6\nChr...
# 6    Love @llamasaid in our Pineapple Party Shirt 🍻...
# 7    🔥 @iamgooby killing it in her custom Drift den...
# 8    FISH BONEZ ☠️ New Color Block + hand printed a...
# 9    Dreaming of warmer days 🌴🍻🌊#ColorBlockCrewww ⚡...
# 10   Acid wash refresh. Shop is OPEN today + filled...
# 11   Oregon surf trip 🙌 #missthis #oregoncoast  @id...
# 12   Cheers to small businesses! 🥂 We’re celebratin...
# 13   AFTER PARTY AT OUR PLACE 🦖🦖🦖 Wine + special di...
# 14   Reworked vintage jackets just hit the site, al...
# 15   Kool kidz ⚡️ @madzap & @brundan_mumbleville al...
# ...

# %%
df.sort_values('taken_at', ascending=False, inplace=True)

# %%
response = requests.get('https://www.instagram.com/graphql/query/?query_id=17888483320059182&variables=%7B%22id%22%3A%222183125078%22%2C%22first%22%3A12%2C%22after%22%3A%22AQB3GUiXeGwoaxyW_RyElWbgcGBbUOIImoB5Z8LaIDV_pWdJ1HUX8p4eIxCTTy51YEMM061kwk1My4rbU8kcqUmzkiXLvOZAXCFRigqerZ_bBA%22%7D')
print(response.status_code)
soup = BeautifulSoup(response.text, "html.parser")
decode = decoder.JSONDecoder()
home_page = decode.decode(str(soup))
for i in range(len(home_page['data']['user']['edge_owner_to_timeline_media']['edges'])):
    sc = home_page['data']['user']['edge_owner_to_timeline_media']['edges'][i]['node']['shortcode']
    print(sc)
    #shortcodes.append(sc)
# Out:
# 200
# BdFyWJOnkVz
# BdDrvIOn_nk
# Bc-glipHgUX
# Bc7ngZ3n1eM
# Bc4zGw4np7e
# Bc2PjwPHKb4
# Bcx4Yr6HUZN
# BcunPF3HIFw
# Bcs1XcwHyBc
# BcpP2G_lQ4V
# BcnC8YIlSqB
# BckSPMDlWGN

# %%
print(scrape.shortcodes)
# Out:
# ['BdFyWJOnkVz', 'BdDrvIOn_nk', 'Bc-glipHgUX', 'Bc7ngZ3n1eM', 'Bc4zGw4np7e', 'Bc2PjwPHKb4', 'Bcx4Yr6HUZN', 'BcunPF3HIFw', 'Bcs1XcwHyBc', 'BcpP2G_lQ4V', 'BcnC8YIlSqB', 'BckSPMDlWGN', 'BcfUxr7Fsus', 'Bcc1Y7xFF4R', 'BcYjQVQFKmA', 'BcXrn3ZF3W-', 'BcVKOuQFxV8', 'BcSPwueFk-z', 'BcP-ggUlSPM', 'BcNvWjwFsie', 'BcLSAD9FuDG', 'BcKMGi9F3Nr', 'BcIW-YclEeC', 'BcF74hGFMCX', 'BcAWeGylbVq', 'Bb60sldFFb5', 'Bb4XtQiFCap', 'Bb15MUal-Ut', 'Bbz55LuFRjZ', 'Bbw45sPFh7D', 'BbpNmG2Fvba', 'BbmyteBF-B3', 'BbZ73wCFGRj', 'BbXThf1lLSV', 'BbVoWMJlwV1', 'BbSTZgyla1L', 'BbNfq6cFOTZ', 'BbINRXcFMS_', 'BbCdRZRFzxL', 'Ba_vSJwFrA3', 'Ba4SAnwlNr2', 'Bay5m44F63d', 'BawjK-wluWT', 'Barb3bYlz00', 'BaeiTL3FWG5', 'BaZS0wll3DO', 'BaSNBsil2Sy', 'BaHZ1_blBQm', 'BaE3jOTFHux', 'BZ9CCj6FgGx', 'BZ34ZdYlMKe', 'BZyof0rFuzY', 'BZtizOSlYp3', 'BZrCnrqFhtH', 'BZpKFJNl7x8', 'BZl64zcFPJK', 'BZjTufLFxCh', 'BZgyWRglJSI', 'BZblCUzFKhc', 'BZZDMWAlrRT', 'BZRXxvTFbwg', 'BZL3EN-F_zR', 'BZJeVqQF0AC', 'BZEeBuLFkb_', 'BZB_MewFqPH', 'BY_0SbClWWT', 'BY8i7m
# ...

# %%
re.findall('..................BeBk2rdnTo_', str(soup))
# Out:
# []
